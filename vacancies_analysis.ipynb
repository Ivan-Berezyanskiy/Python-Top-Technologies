# %%
import os
from datetime import datetime

import numpy as np
import pandas as pd

# %%
df = pd.read_csv("technologies.csv")
df.head()
# Out:
#    applications  experience  max_salary  min_salary  \
# 0             9           2      4000.0      2500.0
# 1             2           5         NaN         NaN
# 2             3           5         NaN         NaN
# 3            12           5         NaN         NaN
# 4            10           5         NaN         NaN
#
#                                                 tags  views
# 0                 back-end,backend,Python,PostgreSQL     43
# 1  Python,React,Material-UI,MySQL,REST API,Google...     11
# 2        Python,backend,Django,Django Rest Framework     24
# 3        Python,PostgreSQL,Knowledge of SQL,highload     26
# 4                                     Node.js,Python     32

# %%
df["experience"] = df["experience"].astype(np.int8)
df = df[df["tags"].notnull()]

# %%
df["tags_category"] = df["tags"].astype("category")

# %%
tags_test = df[df["experience"] == 0]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="0 years",
        xlabel="Technology",
        ylabel="Values",
    )
    top_plot.get_figure().savefig(f"../data/{datetime.today().strftime('%Y-%m-%d')}-0-year")

# %%
tags_test = df[df["experience"] == 1]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="1 years",
        xlabel="Technology",
        ylabel="Values",
        figsize=(12, 6),
        rot=0
    )
    top_plot.get_figure().savefig(os.path.join("data", f"{datetime.today().strftime('%Y-%m-%d')}-1-year"))

# %%
tags_test = df[df["experience"] == 2]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="2 years",
        xlabel="Technology",
        ylabel="Values",
        figsize=(12, 6),
        rot=0
    )
    top_plot.get_figure().savefig(os.path.join("data", f"{datetime.today().strftime('%Y-%m-%d')}-2-year"))

# %%
tags_test = df[df["experience"] == 3]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="3 years",
        xlabel="Technology",
        ylabel="Values",
        figsize=(12, 6),
        rot=0
    )
    top_plot.get_figure().savefig(os.path.join("data", f"{datetime.today().strftime('%Y-%m-%d')}-3-year"))

# %%
tags_test = df[df["experience"] == 5]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="5 years",
        xlabel="Technology",
        ylabel="Values",
        figsize=(12, 6),
        rot=0
    )
    top_plot.get_figure().savefig(os.path.join("data", f"{datetime.today().strftime('%Y-%m-%d')}-5-year"))

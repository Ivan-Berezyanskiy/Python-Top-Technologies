# %%
from datetime import datetime

import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../technologies.csv")
df.head()
# Out:
#    applications  experience  max_salary  min_salary  \
# 0             7           2      4000.0      2500.0
# 1             3           1      2500.0      2000.0
# 2             9           5         NaN         NaN
# 3            12           5         NaN         NaN
# 4             3           5         NaN         NaN
#
#                                                 tags  views
# 0                 back-end,backend,Python,PostgreSQL     33
# 1  Python scripting,Python,Python / Django,Python...     31
# 2                                     Node.js,Python     28
# 3        Python,PostgreSQL,Knowledge of SQL,highload     24
# 4        Python,backend,Django,Django Rest Framework     20

# %%
df["experience"] = df["experience"].astype(np.int8)
df = df[df["tags"].notnull()]

# %%
df["tags_category"] = df["tags"].astype("category")

# %%
tags_test = df[df["experience"] == 0]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="0 years",
        xlabel="Technology",
        ylabel="Values",
    )
    top_plot.get_figure().savefig(f"../data/{datetime.today().strftime('%Y-%m-%d')}-0-year")

# %%
tags_test = df[df["experience"] == 1]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="1 years",
        xlabel="Technology",
        ylabel="Values",
        figsize=(12, 6),
        rot=0
    )
    top_plot.get_figure().savefig(f"../data/{datetime.today().strftime('%Y-%m-%d')}-1-year")

# %%
tags_test = df[df["experience"] == 2]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="2 years",
        xlabel="Technology",
        ylabel="Values",
        figsize=(12, 6),
        rot=0
    )
    top_plot.get_figure().savefig(f"../data/{datetime.today().strftime('%Y-%m-%d')}-2-year")

# %%
tags_test = df[df["experience"] == 3]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="3 years",
        xlabel="Technology",
        ylabel="Values",
        figsize=(12, 6),
        rot=0
    )
    top_plot.get_figure().savefig(f"../data/{datetime.today().strftime('%Y-%m-%d')}-3-year")

# %%
tags_test = df[df["experience"] == 5]["tags_category"].str.get_dummies(",")
if not tags_test.empty:
    top_tags = tags_test.sum().sort_values(ascending=False).head(10)
    top_plot = top_tags.plot.bar(
        title="5 years",
        xlabel="Technology",
        ylabel="Values",
        figsize=(12, 6),
        rot=0
    )
    top_plot.get_figure().savefig(f"../data/{datetime.today().strftime('%Y-%m-%d')}-5-year")
